# %% [markdown]
# # Asset Portfolio Management using Deep Reinforcement Learning
# ---

# %% [markdown]
# ## 8.0 Deep Reinforcement Learning Portfolios

# %% [markdown]
# ### 8.1 Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
matplotlib.use('Agg')
import datetime

from pypfopt.efficient_frontier import EfficientFrontier, objective_functions
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
# Imports from the FinRL Library

from config import config
from backtest import BackTestStats, BaselineStats, BackTestPlot, backtest_strat, baseline_strat
from backtest import backtest_strat, baseline_strat

# %% [markdown]
# ### 8.2 Load Data

# %%
# %store -r train_df
# %store -r test_df

# %%
tech_indicator_list = ['f01','f02','f03','f04']

# %%
train_df.head()
# Out:
#          date   tic      close   high    low       open      volume  \
# 0  2009-03-20   AXP  10.072534  13.19  12.12  13.190000  31088200.0
# 0  2009-03-20   DIS  15.026185  17.98  17.08  17.799999  17766600.0
# 0  2009-03-20    HD  16.652840  22.73  21.76  22.590000  22361800.0
# 0  2009-03-20   IBM  64.557983  95.00  92.18  93.160004  12193900.0
# 0  2009-03-20  INTC  10.250909  15.40  14.35  15.190000  84639100.0
#
#                                             cov_list       f01       f02  \
# 0  [[0.002610715086827884, 0.0012647352623545009,...  1.764112  0.488414
# 0  [[0.002610715086827884, 0.0012647352623545009,...  1.764112  0.488414
# 0  [[0.002610715086827884, 0.0012647352623545009,...  1.764112  0.488414
# 0  [[0.002610715086827884, 0.0012647352623545009,...  1.764112  0.488414
# 0  [[0.002610715086827884, 0.0012647352623545009,...  1.764112  0.488414
#
#         f03       f04
# 0  5.262903  5.777148
# 0  5.262903  5.777148
# 0  5.262903  5.777148
# 0  5.262903  5.777148
# 0  5.262903  5.777148

# %% [markdown]
# ### 8.4 Implement DRL Algorithms

# %%
import env_portfolio
from env_portfolio import StockPortfolioEnv

import models
from models import DRLAgent

# %%
stock_dimension = len(train_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 20

# %%
weights_initial = [1/stock_dimension]*stock_dimension

# %%
env_kwargs = {
    "hmax": 500, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 0,
    'initial_weights': [1/stock_dimension]*stock_dimension
}

# %%
e_train_gym = StockPortfolioEnv(df = train_df, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# #### 8.4.1 Model 1: A2C

# %%
# initialize
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# Logging to tensorboard_log/a2c\a2c_89
# -------------------------------------
# | time/                 |           |
# |    fps                | 93        |
# |    iterations         | 100       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -1.28e+18 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.47e+08  |
# |    std                | 0.997     |
# |    value_loss         | 3.04e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 123       |
# |    iterations         | 200       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -8.32e+19 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 1.96e+08  |
# |    std                | 0.996     |
# |    value_loss         | 5.85e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 300       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -2.94e+20 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 2.76e+08  |
# |    std                | 0.995     |
# |    value_loss         | 1.17e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 137       |
# |    iterations         | 400       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -7.28e+21 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 3.24e+08  |
# |    std                | 0.995     |
# |    value_loss         | 1.6e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4863685.336840701
# Sharpe:  1.3078415758178814
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 144       |
# |    iterations         | 500       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -7.91e+20 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        |
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 167      |
# |    iterations         | 10000    |
# |    time_elapsed       | 298      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -27.3    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9999     |
# |    policy_loss        | 1.1e+08  |
# |    std                | 0.947    |
# |    value_loss         | 2.09e+13 |
# ------------------------------------

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ppo\ppo_22
# -----------------------------
# | time/              |      |
# |    fps             | 154  |
# |    iterations      | 1    |
# |    time_elapsed    | 13   |
# |    total_timesteps | 2048 |
# -----------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4866966.201451803
# Sharpe:  1.3097322863751166
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 141           |
# |    iterations           | 2             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.9557774e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.76e+16     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.04e+15      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -2.58e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.99e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5115771.999360327
# Sharpe:  1.351382553659557
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 152            |
# |    iterations           | 3              |
# |    time_elapsed         | 40             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | -1.6577542e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -5.34e+17      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.12e+15       |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -3.76e-07      |
# |    std                  | 1              |
# |    value_loss           | 2.25e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5034796.148376584
# Sharpe:  1.3430834183421392
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 164           |
# |    iterations           | 4             |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.1175871e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -7.3e+18      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.09e+15      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -3.14e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.44e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4663905.227919282
# Sharpe:  1.2788018770802085
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 167           |
# |    iterations           | 5             |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | -1.322478e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.69e+19     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.35e+15      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -2.28e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.52e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4837456.0579512
# Sharpe:  1.307380512139147
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 175           |
# |    iterations           | 6             |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.1269003e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -2.65e+19     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.2e+15       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -1.83e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.37e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4975940.350133123
# Sharpe:  1.3297010127088258
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 182          |
# |    iterations           | 7            |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 9.126961e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -7.01e+19    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.45e+15     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -3.13e-07    |
# |    std                  | 1            |
# |    value_loss           | 2.64e+15     |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 190            |
# |    iterations           | 8              |
# |    time_elapsed         | 86             |
# |    total_timesteps      | 16384          |
# | train/                  |                |
# |    approx_kl            | -1.1269003e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -1.06e+20      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.33e+15       |
# |    n_updates            | 70             |
# |    policy_gradient_loss | -2.69e-07      |
# |    std                  | 1              |
# |    value_loss           | 2.7e+15        |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4999168.191556744
# Sharpe:  1.3382045005764052
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 195           |
# |    iterations           | 9             |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.6763806e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.44e+20     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.06e+15      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -2.77e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.19e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4801257.795121192
# Sharpe:  1.3036988881913494
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 10           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 5.401671e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -2.69e+20    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.8e+14      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -2.14e-07    |
# |    std                  | 1            |
# |    value_loss           | 2.12e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5084250.372035278
# Sharpe:  1.3463687105937574
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 204            |
# |    iterations           | 11             |
# |    time_elapsed         | 110            |
# |    total_timesteps      | 22528          |
# | train/                  |                |
# |    approx_kl            | -1.7043203e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -5.92e+20      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.06e+15       |
# |    n_updates            | 100            |
# |    policy_gradient_loss | -3.87e-07      |
# |    std                  | 1              |
# |    value_loss           | 2.29e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5065487.551908317
# Sharpe:  1.3456933437188836
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 12           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 6.984919e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -1.01e+21    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.19e+15     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -1.98e-07    |
# |    std                  | 1            |
# |    value_loss           | 2.49e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4908747.914600978
# Sharpe:  1.3163748680744356
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 207           |
# |    iterations           | 13            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 2.0489097e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.1e+21      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.34e+15      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -1.99e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.6e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4679654.9041904835
# Sharpe:  1.2818705851164316
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 14           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 4.656613e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -1.5e+21     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.19e+15     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -3.85e-07    |
# |    std                  | 1            |
# |    value_loss           | 2.59e+15     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 212           |
# |    iterations           | 15            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.8253922e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.53e+21     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.21e+15      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -2.95e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.51e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4725360.660972779
# Sharpe:  1.2918264838442441
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 213           |
# |    iterations           | 16            |
# |    time_elapsed         | 153           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.8626451e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.68e+21     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.09e+15      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -3.3e-07      |
# |    std                  | 1             |
# |    value_loss           | 2.25e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5097006.875170586
# Sharpe:  1.3565627597344123
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 216            |
# |    iterations           | 17             |
# |    time_elapsed         | 160            |
# |    total_timesteps      | 34816          |
# | train/                  |                |
# |    approx_kl            | -1.1827797e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -2.37e+21      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 9.34e+14       |
# |    n_updates            | 160            |
# |    policy_gradient_loss | -1.83e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.96e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5179123.585339768
# Sharpe:  1.3590210524049873
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 219           |
# |    iterations           | 18            |
# |    time_elapsed         | 168           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 1.5739352e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -5.33e+21     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.23e+15      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -2.39e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.4e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5229501.369612654
# Sharpe:  1.3728946543316403
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 221            |
# |    iterations           | 19             |
# |    time_elapsed         | 175            |
# |    total_timesteps      | 38912          |
# | train/                  |                |
# |    approx_kl            | -4.0978193e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -9.89e+21      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.14e+15       |
# |    n_updates            | 180            |
# |    policy_gradient_loss | -2.37e-07      |
# |    std                  | 1              |
# |    value_loss           | 2.6e+15        |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4795980.088376613
# Sharpe:  1.299005266114771
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 224            |
# |    iterations           | 20             |
# |    time_elapsed         | 182            |
# |    total_timesteps      | 40960          |
# | train/                  |                |
# |    approx_kl            | -1.3783574e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -1.12e+22      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.46e+15       |
# |    n_updates            | 190            |
# |    policy_gradient_loss | -3.19e-07      |
# |    std                  | 1              |
# |    value_loss           | 2.74e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4867601.178799312
# Sharpe:  1.313105934801355
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 226           |
# |    iterations           | 21            |
# |    time_elapsed         | 189           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | -9.872019e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.03e+22     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.16e+15      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -1.73e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.47e+15      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 22            |
# |    time_elapsed         | 196           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 2.2351742e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.2e+22      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.35e+15      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -3.02e-07     |
# |    std                  | 1             |
# |    value_loss           | 2.68e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4680802.05242496
# Sharpe:  1.2932345876326619
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 231            |
# |    iterations           | 23             |
# |    time_elapsed         | 203            |
# |    total_timesteps      | 47104          |
# | train/                  |                |
# |    approx_kl            | 1.03376806e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -1.13e+22      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.17e+15       |
# |    n_updates            | 220            |
# |    policy_gradient_loss | -3.21e-07      |
# |    std                  | 1              |
# |    value_loss           | 2.41e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5026466.858885893
# Sharpe:  1.3419170666020142
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 233           |
# |    iterations           | 24            |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 4.0978193e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -1.27e+22     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 9.43e+14      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -2.94e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.93e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4948180.44919107
# Sharpe:  1.3276956009356538
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 25           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 7.916242e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -2.69e+22    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.13e+15     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -2.39e-07    |
# |    std                  | 1            |
# |    value_loss           | 2.32e+15     |
# ------------------------------------------

# %% [markdown]
# #### 8.4.3 Model 3: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ddpg\ddpg_21
# =================================
# begin_total_asset:1000000
# end_total_asset:4915908.762973892
# Sharpe:  1.3320083749132894
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4651111.574868161
# Sharpe:  1.318348122204017
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4651111.574868161
# Sharpe:  1.318348122204017
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4651111.574868161
# Sharpe:  1.318348122204017
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 27        |
# |    time_elapsed    | 340       |
# |    total timesteps | 9496      |
# | train/             |           |
# |    actor_loss      | -7.63e+07 |
# |    critic_loss     | 1.07e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7122      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4651111.574868161
# Sharpe:  1.318348122204017
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4651111.574868161
# Sharpe:  1.318348122204017
# =================================

# %% [markdown]
# ### 8.5 Fittng Model on Training Data

# %%
# A2C Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_train_daily_return, a2c_train_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
# PPO Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_train_daily_return, ppo_train_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
# DDPG Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_train_daily_return, ddpg_train_weights = DRLAgent.DRL_prediction(model=trained_ddpg,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
# Store the Training Models
# %store a2c_train_daily_return
# %store ppo_train_daily_return
# %store ddpg_train_daily_return

# %% [markdown]
# ### 8.6 Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the DDPG model to trade Dow jones 30 stocks.

# %%
test_df.head(3)

# %%
# A2C Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_test_daily_return, a2c_test_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
a2c_test_daily_return.head()

# %%
a2c_test_weights.to_csv('a2c_test_weights.csv')

# %%
a2c_test_weights.head()

# %%
# PPO Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_test_daily_return, ppo_test_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
ppo_test_weights.to_csv('ppo_test_weights')

# %%
# DDPG Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_test_daily_return, ddpg_test_weights = DRLAgent.DRL_prediction(model=trained_ddpg,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)

# %%
ddpg_test_weights.to_csv('ddpg_test_weights')

# %% [markdown]
# ### 8.7 Save the Portfolios

# %%
a2c_test_portfolio = a2c_test_daily_return.copy()
a2c_test_returns = a2c_test_daily_return.copy()

ppo_test_portfolio = ppo_test_daily_return.copy()
ppo_test_returns = ppo_test_daily_return.copy()

ddpg_test_portfolio = ddpg_test_daily_return.copy()
ddpg_test_returns = ddpg_test_daily_return.copy()

# %%
# %store a2c_test_portfolio
# %store a2c_test_returns 

# %store ppo_test_portfolio
# %store ppo_test_returns 

# %store ddpg_test_portfolio
# %store ddpg_test_returns
