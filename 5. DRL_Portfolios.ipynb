# %% [markdown]
# # Asset Portfolio Management using Deep Reinforcement Learning
# ---

# %% [markdown]
# ## 5.0 Deep Reinforcement Learning Portfolios

# %% [markdown]
# ### 5.1 Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
import datetime

# %%
# Imports from the FinRL Library

from finrl.config import config
from finrl.trade.backtest import BackTestStats, BaselineStats, BackTestPlot, backtest_strat, baseline_strat
from finrl.trade.backtest import backtest_strat, baseline_strat

import sys
sys.path.append("../FinRL-Library")
# Out:
# C:\Users\Musonda\anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# ### 5.2 Load Data

# %%
# %store -r train_df
# %store -r test_df

# %%
train_df.head(3)
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-12-31   7.611786   7.619643   7.520000   6.492372  352410800.0  AAPL
# 0  2009-12-31  40.900002  41.080002  40.490002  34.291534    4030500.0   AXP
# 0  2009-12-31  55.000000  55.220001  54.049999  41.856789    2189400.0    BA
#
#          atr        bbw           obv        cmf      macd        adx  \
# 0   1.089849  14.391304  1.847973e+10 -14.498982  0.106168  20.032052
# 0   6.638453   7.839731  4.883513e+10 -14.537243  0.324763  23.340487
# 0  12.891344   4.916607  6.798863e+10 -26.245485  0.444625  16.902318
#
#          sma        ema         cci        rsi  \
# 0   6.237017   6.309319  141.146843  64.127926
# 0  34.681527  34.582270   16.078828  50.694489
# 0  42.400007  42.370060  -75.723504  49.726875
#
#                                             cov_list
# 0  [[0.17945278689647873, 0.22869766853329948, 0....
# 0  [[0.17945278689647873, 0.22869766853329948, 0....
# 0  [[0.17945278689647873, 0.22869766853329948, 0....

# %%
tech_indicator_list = ['atr', 'bbw','obv','cmf','macd', 'adx', 'sma', 'ema', 'cci', 'rsi']

# %% [markdown]
# ### 5.4 Implement DRL Algorithms

# %%
import env_portfolio
from env_portfolio import StockPortfolioEnv

import models
from models import DRLAgent

# %%
stock_dimension = len(train_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 30

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockPortfolioEnv(df = train_df, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# #### 5.4.1 Model 1: A2C

# %%
# initialize
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# Logging to tensorboard_log/a2c\a2c_12
# ------------------------------------
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 100      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.51e+08 |
# |    std                | 0.997    |
# |    value_loss         | 1.57e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 27       |
# |    iterations         | 200      |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 199      |
# |    policy_loss        | 2.38e+08 |
# |    std                | 0.997    |
# |    value_loss         | 3.88e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 36       |
# |    iterations         | 300      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 299      |
# |    policy_loss        | 2.95e+08 |
# |    std                | 0.997    |
# |    value_loss         | 5.48e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 43       |
# |    iterations         | 400      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -42.5    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 399      |
# |    policy_loss        | 4.12e+08 |
# |    std                | 0.996    |
# |    value_loss         | 1.05e+14 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3404896.2046931516
# Sharpe:  1.0669347073144049
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 49       |
# |    iterations         | 500      |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.74e+08 |
# |    std                | 0.996    |
# |    value_loss         | 1.49e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 53       |
# |    iterations         | 600      |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.87e+08 |
# |    std                | 0.996    |
# |    value_loss         | 2.55e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 57       |
# |    iterations         | 700      |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 699      |
# |    policy_loss        | 2.59e+08 |
# |    std                | 0.995    |
# |    value_loss         | 5.27e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 61       |
# |    iterations         | 800      |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0002   |
# |    n_updates          |
------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3586009.99038301
# Sharpe:  1.1077511963397075
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 154           |
# |    iterations           | 2             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.3038516e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -2.62e+16     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.27e+14      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -7.04e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.21e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3743783.789960841
# Sharpe:  1.145616781203152
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 149           |
# |    iterations           | 3             |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.4342368e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -8.01e+15     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.99e+14      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -7.1e-07      |
# |    std                  | 1             |
# |    value_loss           | 1.2e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3607287.8042296343
# Sharpe:  1.1130205700411566
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 4           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 3.46452e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | -1.75e+16   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.59e+14    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -9.24e-07   |
# |    std                  | 1           |
# |    value_loss           | 1.25e+15    |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3742159.298103902
# Sharpe:  1.1423794655147224
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 150           |
# |    iterations           | 5             |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | -4.284084e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -3.75e+16     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.22e+14      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -5.58e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.27e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3762464.450980636
# Sharpe:  1.1463924130400105
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 149           |
# |    iterations           | 6             |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | -5.401671e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -8.44e+16     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 7.06e+14      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -7.13e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.35e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3532244.265129815
# Sharpe:  1.0959179279624092
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 7             |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 2.0489097e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -1.7e+17      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.95e+14      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -4.76e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.35e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3490476.6669185674
# Sharpe:  1.0832333327974593
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 150            |
# |    iterations           | 8              |
# |    time_elapsed         | 108            |
# |    total_timesteps      | 16384          |
# | train/                  |                |
# |    approx_kl            | -2.1979213e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -2.33e+17      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 5.98e+14       |
# |    n_updates            | 70             |
# |    policy_gradient_loss | -7.84e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.27e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3362029.394549191
# Sharpe:  1.0550174052027155
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 9              |
# |    time_elapsed         | 121            |
# |    total_timesteps      | 18432          |
# | train/                  |                |
# |    approx_kl            | -1.5087426e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -3.97e+17      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.37e+14       |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -8.12e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.29e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3714878.602988653
# Sharpe:  1.1351295397230745
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 10           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 4.004687e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -5.46e+17    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.82e+14     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -7.08e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.22e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3526665.1509857476
# Sharpe:  1.0954194628562457
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 152          |
# |    iterations           | 11           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 1.359731e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -7.76e+17    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.61e+14     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -6.29e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.37e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3516005.9043333866
# Sharpe:  1.0880081741388679
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 152           |
# |    iterations           | 12            |
# |    time_elapsed         | 160           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 3.7252903e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -8.67e+17     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.23e+14      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -6.34e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.3e+15       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3719472.4907969567
# Sharpe:  1.13928790415645
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 152            |
# |    iterations           | 13             |
# |    time_elapsed         | 174            |
# |    total_timesteps      | 26624          |
# | train/                  |                |
# |    approx_kl            | -2.3283064e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -1.2e+18       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.28e+14       |
# |    n_updates            | 120            |
# |    policy_gradient_loss | -4.55e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.33e+15       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 153           |
# |    iterations           | 14            |
# |    time_elapsed         | 186           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 4.4703484e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -1.82e+18     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 7.53e+14      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -6.1e-07      |
# |    std                  | 1             |
# |    value_loss           | 1.46e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3630636.236728986
# Sharpe:  1.1202347665977404
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 153           |
# |    iterations           | 15            |
# |    time_elapsed         | 199           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | -6.891787e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -1.83e+18     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.95e+14      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -8.32e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.19e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3324381.8512790767
# Sharpe:  1.04641260160608
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 153            |
# |    iterations           | 16             |
# |    time_elapsed         | 214            |
# |    total_timesteps      | 32768          |
# | train/                  |                |
# |    approx_kl            | -3.3713877e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -1.85e+18      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 5.32e+14       |
# |    n_updates            | 150            |
# |    policy_gradient_loss | -7.78e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.05e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3730976.7819488854
# Sharpe:  1.1402191720793764
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 152            |
# |    iterations           | 17             |
# |    time_elapsed         | 228            |
# |    total_timesteps      | 34816          |
# | train/                  |                |
# |    approx_kl            | -1.5459955e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -2.85e+18      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.18e+14       |
# |    n_updates            | 160            |
# |    policy_gradient_loss | -5.53e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.19e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3553252.8913591523
# Sharpe:  1.1008753648063603
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 18            |
# |    time_elapsed         | 242           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 4.8428774e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -5.11e+18     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.98e+14      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -7.53e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.26e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3755358.0457875743
# Sharpe:  1.1462773234248598
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 150           |
# |    iterations           | 19            |
# |    time_elapsed         | 257           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | -1.899898e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -5.29e+18     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.63e+14      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -3.49e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.28e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3587144.5603054375
# Sharpe:  1.1055086376341339
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 20            |
# |    time_elapsed         | 270           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 3.5390258e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -7.67e+18     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.95e+14      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -2.37e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.32e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3940677.4126689467
# Sharpe:  1.1834827379171937
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 21           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 4.582107e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -8.94e+18    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.29e+14     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -6.57e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.29e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3496008.4591870974
# Sharpe:  1.0876568506989415
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 22           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 8.940697e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -1.5e+19     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.58e+14     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -5.96e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.49e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3773081.0522090415
# Sharpe:  1.1489478009042713
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 23           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | -3.46452e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -1.64e+19    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.56e+14     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -6.77e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.29e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3582432.41908991
# Sharpe:  1.1115045113088495
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 24            |
# |    time_elapsed         | 324           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.2665987e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -1.91e+19     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.26e+14      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -5.64e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.47e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3690966.6878413637
# Sharpe:  1.1317157506139277
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 25            |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | -6.509945e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -1.82e+19     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.73e+14      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -6.4e-07      |
# |    std                  | 1             |
# |    value_loss           | 1.36e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3643630.0926035745
# Sharpe:  1.1240022766145739
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 26             |
# |    time_elapsed         | 352            |
# |    total_timesteps      | 53248          |
# | train/                  |                |
# |    approx_kl            | -1.3038516e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -2.58e+19      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.5e+14        |
# |    n_updates            | 250            |
# |    policy_gradient_loss | -3.79e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.43e+15       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 27            |
# |    time_elapsed         | 365           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.6018748e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -2.73e+19     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.92e+14      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -5.45e-07     |
# |    std                  | 1             |
# |    value_loss           | 1.39e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3783601.6915341998
# Sharpe:  1.1519576352470184
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 150            |
# |    iterations           | 28             |
# |    time_elapsed         | 380            |
# |    total_timesteps      | 57344          |
# | train/                  |                |
# |    approx_kl            | -1.2759119e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -3.1e+19       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.84e+14       |
# |    n_updates            | 270            |
# |    policy_gradient_loss | -5.38e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.31e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3515356.370611333
# Sharpe:  1.0893477007755166
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 150            |
# |    iterations           | 29             |
# |    time_elapsed         | 394            |
# |    total_timesteps      | 59392          |
# | train/                  |                |
# |    approx_kl            | -5.5879354e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -2.54e+19      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 5.64e+14       |
# |    n_updates            | 280            |
# |    policy_gradient_loss | -6.58e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.08e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3858183.1069397903
# Sharpe:  1.1660381697585982
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 150           |
# |    iterations           | 30            |
# |    time_elapsed         | 408           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 2.3283064e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.6         |
# |    explained_variance   | -3.8e+19      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.14e+14      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -1.08e-06     |
# |    std                  | 1             |
# |    value_loss           | 1.23e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3592581.618211691
# Sharpe:  1.1047708489647239
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 150            |
# |    iterations           | 31             |
# |    time_elapsed         | 421            |
# |    total_timesteps      | 63488          |
# | train/                  |                |
# |    approx_kl            | -2.9057264e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -6.31e+19      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.32e+14       |
# |    n_updates            | 300            |
# |    policy_gradient_loss | -3.36e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.31e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3869057.823494393
# Sharpe:  1.1683847264189184
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 150            |
# |    iterations           | 32             |
# |    time_elapsed         | 434            |
# |    total_timesteps      | 65536          |
# | train/                  |                |
# |    approx_kl            | -1.8626451e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -6.59e+19      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.33e+14       |
# |    n_updates            | 310            |
# |    policy_gradient_loss | -6.17e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.31e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3655354.8017023215
# Sharpe:  1.1229709594055823
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 33             |
# |    time_elapsed         | 446            |
# |    total_timesteps      | 67584          |
# | train/                  |                |
# |    approx_kl            | -3.1851232e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -9.67e+19      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.41e+14       |
# |    n_updates            | 320            |
# |    policy_gradient_loss | -5.96e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.39e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3520727.099822903
# Sharpe:  1.0944308856527796
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 34             |
# |    time_elapsed         | 460            |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | -4.0978193e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -9.76e+19      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.06e+14       |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -5.51e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.31e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3575230.9931928036
# Sharpe:  1.1035542268245768
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 35             |
# |    time_elapsed         | 473            |
# |    total_timesteps      | 71680          |
# | train/                  |                |
# |    approx_kl            | -3.3155084e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -1.11e+20      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 5.92e+14       |
# |    n_updates            | 340            |
# |    policy_gradient_loss | -7.94e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.28e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3752431.5849570986
# Sharpe:  1.1463013975876004
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 36             |
# |    time_elapsed         | 486            |
# |    total_timesteps      | 73728          |
# | train/                  |                |
# |    approx_kl            | -1.4156103e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -1.61e+20      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.12e+14       |
# |    n_updates            | 350            |
# |    policy_gradient_loss | -6.09e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.31e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3693570.9882558226
# Sharpe:  1.1353062287718179
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 37           |
# |    time_elapsed         | 500          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 6.146729e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -1.95e+20    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 8.2e+14      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -3.91e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.49e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3767515.574785008
# Sharpe:  1.1492788785549575
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 38           |
# |    time_elapsed         | 513          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 3.222376e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -1.79e+20    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.84e+14     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -9.52e-07    |
# |    std                  | 1            |
# |    value_loss           | 1.41e+15     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3662868.385353852
# Sharpe:  1.1220467292296628
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 151            |
# |    iterations           | 39             |
# |    time_elapsed         | 528            |
# |    total_timesteps      | 79872          |
# | train/                  |                |
# |    approx_kl            | -1.8626451e-09 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -42.6          |
# |    explained_variance   | -2.32e+20      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.84e+14       |
# |    n_updates            | 380            |
# |    policy_gradient_loss | -4.29e-07      |
# |    std                  | 1              |
# |    value_loss           | 1.48e+15       |
# --------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 150        |
# |    iterations           | 40         |
# |    time_elapsed         | 542        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 2.8871e-07 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.6      |
# |    explained_variance   | -2.47e+20  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.42e+14   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -6.75e-07  |
# |    std                  | 1          |
# |    value_loss           | 1.42e+15   |
# ----------------------------------------

# %% [markdown]
# #### 5.4.3 Model 3: DDPG

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ddpg\ddpg_4
# =================================
# begin_total_asset:1000000
# end_total_asset:3810748.1872714735
# Sharpe:  1.183654806403746
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 15       |
# |    time_elapsed    | 563      |
# |    total timesteps | 8860     |
# | train/             |          |
# |    actor_loss      | 1.63e+07 |
# |    critic_loss     | 1.84e+13 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6645     |
# ---------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 13        |
# |    time_elapsed    | 1319      |
# |    total timesteps | 17720     |
# | train/             |           |
# |    actor_loss      | -5.75e+07 |
# |    critic_loss     | 8.42e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15505     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 13        |
# |    time_elapsed    | 2043      |
# |    total timesteps | 26580     |
# | train/             |           |
# |    actor_loss      | -8.85e+07 |
# |    critic_loss     | 8.05e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24365     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 12        |
# |    time_elapsed    | 2783      |
# |    total timesteps | 35440     |
# | train/             |           |
# |    actor_loss      | -1.31e+08 |
# |    critic_loss     | 1.45e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33225     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 12        |
# |    time_elapsed    | 3567      |
# |    total timesteps | 44300     |
# | train/             |           |
# |    actor_loss      | -1.57e+08 |
# |    critic_loss     | 1.88e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42085     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================

# %% [markdown]
# ### 5.5 Training Models

# %%
# A2C Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_train_daily_return, a2c_train_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:3502150.5010687886
# Sharpe:  1.0789379424597758
# =================================

# %%
# PPO Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_train_daily_return, ppo_train_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:3685175.5565437987
# Sharpe:  1.1277054479499276
# =================================

# %%
# DDPG Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_train_daily_return, ddpg_train_weights = DRLAgent.DRL_prediction(model=trained_ddpg,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:3796307.734087349
# Sharpe:  1.182186906834218
# =================================

# %%
# Store the Training Models
# %store a2c_train_daily_return
# %store ppo_train_daily_return
# %store ddpg_train_daily_return
# Out:
# Stored 'a2c_train_daily_return' (DataFrame)
# Stored 'ppo_train_daily_return' (DataFrame)
# Stored 'ddpg_train_daily_return' (DataFrame)

# %% [markdown]
# ### 5.6 Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the DDPG model to trade Dow jones 30 stocks.

# %%
test_df.head(3)
# Out:
#          date        open        high         low       close       volume  \
# 0  2018-10-19   54.514999   55.314999   54.357498   53.367214  132314800.0
# 0  2018-10-19  104.059998  107.550003  104.059998  103.342613    5726300.0
# 0  2018-10-19  359.799988  359.869995  354.209991  344.585480    3491600.0
#
#     tic        atr        bbw           obv       cmf      macd        adx  \
# 0  AAPL   2.209832   8.231327  3.395175e+10 -2.616712 -0.079059  18.194248
# 0   AXP   4.737382   8.736579  4.908848e+10 -4.251619 -0.694974  23.736835
# 0    BA  15.690117  12.552809  6.859095e+10 -3.196253 -0.220696  23.929039
#
#           sma         ema         cci        rsi  \
# 0   53.775824   53.670425  -63.161543  48.313484
# 0  101.471449  101.605906   -7.348819  53.613308
# 0  358.004206  354.118657 -106.642111  41.761613
#
#                                             cov_list
# 0  [[0.5356040816995599, 0.1799444253900448, 0.23...
# 0  [[0.5356040816995599, 0.1799444253900448, 0.23...
# 0  [[0.5356040816995599, 0.1799444253900448, 0.23...

# %%
# A2C Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_test_daily_return, a2c_test_weights = DRLAgent.DRL_prediction(model=trained_a2c,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1243936.140327598
# Sharpe:  0.5046117454037728
# =================================

# %%
a2c_test_daily_return.head()
# Out:
#          date  daily_return
# 0  2018-10-19      0.000000
# 1  2018-10-22     -0.005321
# 2  2018-10-23     -0.006090
# 3  2018-10-24     -0.024084
# 4  2018-10-25      0.015915

# %%
a2c_test_weights.to_csv('a2c_test_weights.csv')

# %%
# PPO Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_test_daily_return, ppo_test_weights = DRLAgent.DRL_prediction(model=trained_ppo,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1252240.5695058317
# Sharpe:  0.5144669353361637
# =================================

# %%
ppo_test_weights.to_csv('ppo_test_weights')

# %%
# DDPG Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_test_daily_return, ddpg_test_weights = DRLAgent.DRL_prediction(model=trained_ddpg,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1309115.636857007
# Sharpe:  0.6028317431500818
# =================================

# %%
ddpg_test_weights.to_csv('ddpg_test_weights')

# %% [markdown]
# ### 5.7 Save the Portfolios

# %%
a2c_test_portfolio = a2c_test_daily_return.copy()
a2c_test_returns = a2c_test_daily_return.copy()

ppo_test_portfolio = ppo_test_daily_return.copy()
ppo_test_returns = ppo_test_daily_return.copy()

ddpg_test_portfolio = ddpg_test_daily_return.copy()
ddpg_test_returns = ddpg_test_daily_return.copy()

# %%
# %store a2c_test_portfolio
# %store a2c_test_returns 

# %store ppo_test_portfolio
# %store ppo_test_returns 

# %store ddpg_test_portfolio
# %store ddpg_test_returns
# Out:
# Stored 'a2c_test_portfolio' (DataFrame)
# Stored 'a2c_test_returns' (DataFrame)
# Stored 'ppo_test_portfolio' (DataFrame)
# Stored 'ppo_test_returns' (DataFrame)
# Stored 'ddpg_test_portfolio' (DataFrame)
# Stored 'ddpg_test_returns' (DataFrame)
